# %%
import random
comp_wins=0
player_wins=0

def choose_option():
    user_choice=input("choose Rock,Paper or sessiors")
    if user_choice in["Rock","rock","r"]:
        user_choice="r"
    elif user_choice in["Paper","paper","p"]:
        user_choice="p"
    elif user_choice in["Sessior","sessior","s"]:
        user_choice="s"
    else:
        print("Please try again")
        choose_option()
    return  user_choice 
def computer_option():
    comp_choice=random.randint(1,3)
    if comp_choice==1:
        comp_choice="r"
        #print("rock")
    elif comp_choice==2:
        #print("paper")
        comp_choice=="p"
    elif comp_choice==3:
       # print("sessiors")
        comp_choice=="s"
    return comp_choice
while True:
    print("")
    user_choice=choose_option()
    comp_choice=computer_option()
    print("")
    
    
    if user_choice=="r":
        if comp_choice=="r":
            print("you both got the same , so you tied")
        elif comp_choice=="p":
            print("You loose since comp choose paper")
            comp_wins+=1
        elif comp_choice=="s":
            print("You win since comp choose sessors")
            player_wins+=1
     
    elif user_choice=="p":
        if comp_choice=="p":
            print("you both got the same , so you tied")
        elif comp_choice=="r":
            print("You win since comp choose rock")
            player_wins+=1
        elif comp_choice=="s":
            print("You loose  since comp choose sessors")
            comp_wins+=1
    elif user_choice=="s":
        if comp_choice=="s":
            print("you both got the same , so you tied")
        elif comp_choice=="r":
            print("You loose since comp choose rock")
            comp_wins+=1
        elif comp_choice=="p":
            print("You win  since comp choose paper")
            player_wins+=1
                                  
    print("")
    print("Player wins", str(player_wins))
    print("comp wins", str(comp_wins))

    user_choice=input("do you want to play: y/n?")
    if user_choice in["Y","y","yes"]:
        pass
    elif user_choice["No","no","n"]:
        break
    else:
        break
# Out:
# choose Rock,Paper or sessiorsp
#
# You win since comp choose rock
#
# Player wins 1
# comp wins 0
